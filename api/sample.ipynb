# %%
mapping = None
reverse_mapping = None
predecessors = None
dist_matrix = None
actor_info_df = None
import json
import numpy as np
import pandas as pd
with open("mapping.json") as file:
    mapping = json.load(file)
with open("predecessors.npy", "rb") as file:
    predecessors = np.load(file)
with open("dist_matrix.npy", "rb") as file:
    dist_matrix = np.load(file)
reverse_mapping = dict([(value, key) for key, value in mapping.items()])
actor_info_df = pd.read_csv('actor_info.csv')

# %%
actor_info_df
# Out:
#          nconst       primaryName birthYear deathYear  \
# 0     nm0000002     Lauren Bacall      1924      2014
# 1     nm0000008     Marlon Brando      1924      2004
# 2     nm0000084           Gong Li      1965        \N
# 3     nm0000092       John Cleese      1939        \N
# 4     nm0000093         Brad Pitt      1963        \N
# ...         ...               ...       ...       ...
# 2941  nm9855560          Fm Babai        \N        \N
# 2942  nm9876442       Vishwak Sen      1995        \N
# 2943  nm9884007    Nishvika Naidu      1996        \N
# 2944  nm9957529  Balwinder Bullet        \N        \N
# 2945  nm9963212         Raju Maan        \N        \N
#
#                       primaryProfession  \
# 0                    actress,soundtrack
# 1             actor,soundtrack,director
# 2                      actress,producer
# 3                 actor,writer,producer
# 4             producer,actor,soundtrack
# ...                                 ...
# 2941                       actor,writer
# 2942  actor,director,make_up_department
# 2943                            actress
# 2944                              actor
# 2945                              actor
#
#                                    knownForTitles
# 0         tt0037382,tt0117057,tt0075213,tt0038355
# 1         tt0078788,tt0068646,tt0047296,tt0070849
# 2         tt0430357,tt0101640,tt0397535,tt0473444
# 3         tt0063929,tt0095159,tt0085959,tt0071853
# 4         tt0356910,tt2935510,tt1210166,tt0114746
# ...                                           ...
# 2941   tt21844034,tt21198540,tt15446066,tt7392212
# 2942    tt23745844,tt9799984,tt11490170,tt8680096
# 2943   tt15302500,tt11470290,tt14773866,tt8364128
# 2944  tt22045080,tt14888342,tt15979440,tt15170410
# 2945   tt0319165,tt10346016,tt11617422,tt11617702
#
# [2946 rows x 6 columns]

# %%
actor_info_df.loc[actor_info_df['primaryName'] == "Amitabh Bachchan"]
# Out:
#         nconst       primaryName birthYear deathYear  \
# 340  nm0000821  Amitabh Bachchan      1942        \N
#
#                primaryProfession                           knownForTitles
# 340  music_artist,actor,producer  tt0213890,tt0337578,tt5571734,tt0375611

# %%
def get_path(Pr, i, j):
    """Gets the path between 2 IDs"""
    i = mapping[i]
    j = mapping[j]
    path = [j]
    k = j
    while Pr[i, k] != -9999:
        path.append(Pr[i, k])
        k = Pr[i, k]
    return list(map(lambda x: reverse_mapping[x], path[::-1]))

# %%
amitabh = 'nm0000821'
feroz = 'nm9957529'
p = get_path(predecessors, amitabh, feroz)
names_out = list(map(lambda x: (actor_info_df[actor_info_df['nconst'] == x])['primaryName'].values[0], p))

# %%
names_out
# Out:
# ['Amitabh Bachchan']
